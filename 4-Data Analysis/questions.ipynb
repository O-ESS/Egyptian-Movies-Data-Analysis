# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

# %%
df = pd.read_csv('df_imputed&cleaned.csv')

# %% [markdown]
# # Best Director per decade

# %%
from numpy.core.numeric import NaN
df40s = df[(df['تاريخ العرض']<1950 )& (df['تاريخ العرض']>=1940)]
df50s = df[(df['تاريخ العرض']<1960) & (df['تاريخ العرض']>=1950)]
df60s = df[(df['تاريخ العرض']<1970) & (df['تاريخ العرض']>=1960)]
df70s = df[(df['تاريخ العرض']<1980) & (df['تاريخ العرض']>=1970)]
tem = df40s['إخراج']
director40s = np.array([])
for st in tem:
  if(type(st)!=str):
      continue
  lis = st.split(",")
  director40s=np.append(director40s, lis);

tem = df50s['إخراج']
director50s = np.array([])
for st in tem:
  if(type(st)!=str):
      continue
  lis = st.split(",")
  director50s=np.append(director50s, lis);

tem = df60s['إخراج']
director60s = np.array([])
for st in tem:
  if(type(st)!=str):
      continue
  lis = st.split(",")
  director60s=np.append(director60s, lis);

tem = df70s['إخراج']
director70s = np.array([])
for st in tem:
  if(type(st)!=str):
      continue
  lis = st.split(",")
  director70s=np.append(director70s, lis);
director40su = np.unique(director40s)
count40s = np.array([])
for m in director40su:
  c = 0
  for m1 in director40s:
    if m==m1:
      c = c+1
  count40s = np.append(count40s,[c])

director50su = np.unique(director50s)
count50s = np.array([])
for m in director50su:
  c = 0
  for m1 in director50s:
    if m==m1:
      c = c+1
  count50s = np.append(count50s,[c])

director60su = np.unique(director60s)
count60s = np.array([])
for m in director60su:
  c = 0
  for m1 in director60s:
    if m==m1:
      c = c+1
  count60s = np.append(count60s,[c])

director70su = np.unique(director70s)
count70s = np.array([])
for m in director70su:
  c = 0
  for m1 in director70s:
    if m==m1:
      c = c+1
  count70s = np.append(count70s,[c])

# %%
np.argpartition(count50s, -2)[-2:]
# Out:
# array([62, 77])

# %%
count50s,count50s[62],count50s[77]
# Out:
# (array([ 2.,  4., 15.,  4., 14.,  1.,  1., 12.,  1.,  1., 13.,  1.,  9.,
#          6.,  1.,  1.,  1.,  1.,  1., 15.,  7.,  1.,  5., 14., 10., 11.,
#          1.,  1., 17.,  3.,  2.,  2.,  1.,  1., 10.,  1.,  3.,  4., 15.,
#          1.,  5.,  7.,  8.,  4.,  1.,  2.,  1.,  1.,  2., 24.,  2.,  2.,
#          6.,  1.,  2.,  1.,  1.,  3.,  7., 17., 30.,  2., 36.,  3.,  3.,
#          1.,  8.,  7.,  1., 16.,  1.,  3.,  1.,  8.,  4., 22.,  5., 39.,
#         12.,  2.,  1.,  3.,  1.,  1.,  1.,  1.,  1., 27.,  1.,  2.,  4.,
#          1., 12.,  8.,  1.,  1.,  8., 15., 17.,  1.,  1.,  1., 10., 15.,
#         14.,  1.,  1., 14., 20., 34.,  1., 17.,  1.,  1.,  1., 13.,  1.,
#         23., 16.,  1., 17.,  1.,  1.,  1.,  1.,  2.,  1., 19.,  1.,  9.,
#          1., 14., 23.,  1.,  6.,  2.,  1.,  1.,  2.,  8.,  1.,  1.,  1.,
#         13.,  3.,  1.,  1.,  4.,  1.,  1., 23.,  1.,  4.,  4.,  1.,  1.,
#          3.,  4.,  2.,  1., 16.,  1., 14.,  7.,  1.,  2.,  1.,  1.,  1.,
# ...

# %%
ind = np.argpartition(count40s, -10)[-10:]
director40su=director40su[ind]
count40s=count40s[ind]

ind = np.argpartition(count50s, -10)[-10:]
director50su=director50su[ind]
count50s=count50s[ind]

ind = np.argpartition(count60s, -10)[-10:]
director60su=director60su[ind]
count60s=count60s[ind]

ind = np.argpartition(count70s, -10)[-10:]
director70su=director70su[ind]
count70s=count70s[ind]

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))

ax1.bar(director40su, count40s)
ax1.set_xticklabels(np.unique(director40s), rotation=90);
ax1.set_ylabel('Movies Count')
ax1.set_title('40s')

ax2.bar(director50su, count50s)
ax2.set_xticklabels(np.unique(director50s), rotation=90);
ax2.set_ylabel('Movies Count')
ax2.set_title('50s')

ax3.bar(director60su, count60s)
ax3.set_xticklabels(np.unique(director60s), rotation=90);
ax3.set_ylabel('Movies Count')
ax3.set_title('50s')

ax4.bar(director70su, count70s)
ax4.set_xticklabels(np.unique(director70s), rotation=90);
ax4.set_ylabel('Movies Count')
ax4.set_title('70s')
# Out:
# Text(0.5, 1.0, '70s')

# %%
a =[get_display(arabic_reshaper.reshape(k)) for k in director40su]
b=count40s
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
a =[get_display(arabic_reshaper.reshape(k)) for k in director50su]
b=count50s
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
a =[get_display(arabic_reshaper.reshape(k)) for k in director60su]
b=count60s
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
a =[get_display(arabic_reshaper.reshape(k)) for k in director70su]
b=count70s
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %% [markdown]
# # Best actor per category

# %%
df = pd.read_csv('df_imputed&cleaned.csv')

# %%
df_category = df.groupby(['تصنيف الفيلم', 'بطولة اولي']).count().sort_values(by=['اسم الفيلم'], ascending=False)
newDf=df_category.reset_index()

# %%
drama=newDf[newDf['تصنيف الفيلم']=='دراما']
drama=drama.head(10)
drama = drama[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
drama.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in drama["actor"]]
b=drama['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
romance=newDf[newDf['تصنيف الفيلم']=='رومانسي']
romance=romance.head(10)
romance = romance[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
romance.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in romance["actor"]]
b=romance['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
comedy=newDf[newDf['تصنيف الفيلم']=='كوميدي']
comedy=comedy.head(10)
comedy = comedy[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
comedy.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in comedy["actor"]]
b=comedy['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
action=newDf[newDf['تصنيف الفيلم']=='ﺗﺸﻮﻳﻖ ﻭﺇﺛﺎﺭﺓ']
action=action.head(10)
action = action[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
action.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in action["actor"]]
b=action['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %% [markdown]
# ## Best actor per Decade

# %%
df = pd.read_csv('df_imputed&cleaned.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0 اسم الفيلم  تاريخ العرض  ...           إخراج       توزيع بطولة اولي
# 0           0      رابحة         1945  ...     نيازي مصطفى         NaN       كوكا
# 1           1    فتح مصر         1948  ...  فؤاد الجزايرلي  ستوديو مصر  لولا صدقي
#
# [2 rows x 17 columns]

# %%
the40= df[(df['تاريخ العرض']>=1940) & (df['تاريخ العرض']<1950)].groupby(['بطولة اولي']).count().sort_values(by=['اسم الفيلم'], ascending=False)
the40=the40.reset_index()

the50= df[(df['تاريخ العرض']>=1950) & (df['تاريخ العرض']<1960)].groupby(['بطولة اولي']).count().sort_values(by=['اسم الفيلم'], ascending=False)
the50=the50.reset_index()

the60= df[(df['تاريخ العرض']>=1960) & (df['تاريخ العرض']<1970)].groupby(['بطولة اولي']).count().sort_values(by=['اسم الفيلم'], ascending=False)
the60=the60.reset_index()

the70= df[(df['تاريخ العرض']>=1970) & (df['تاريخ العرض']<1980)].groupby(['بطولة اولي']).count().sort_values(by=['اسم الفيلم'], ascending=False)
the70=the70.reset_index()

# %%
the40=the40.head(10)
the40 = the40[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
the40.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in the40["actor"]]
b=the40['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
the50=the50.head(10)
the50 = the50[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
the50.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in the50["actor"]]
b=the50['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
the60=the60.head(10)
the60 = the60[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
the60.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in the60["actor"]]
b=the60['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %%
the70=the70.head(10)
the70 = the70[["بطولة اولي",'اسم الفيلم']]  # we are interested in rating and review only
the70.columns = ["actor", "count"]

a =[get_display(arabic_reshaper.reshape(k)) for k in the70["actor"]]
b=the70['count']
d = {'':a,'count':b}
df = pd.DataFrame(d)
df=df.sort_values(by="count",ascending=False)

sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.barplot(x="count", y="", data=df)

# %% [markdown]
# # relation between category and film duration

# %%
df = pd.read_csv('df_imputed&cleaned.csv')

# %%
df_duration = df.groupby(['تصنيف الفيلم']).mean()
df_duration
# Out:
#               Unnamed: 0  تاريخ العرض  مدة الفيلم (دقيقة)
# تصنيف الفيلم
# استعراضي          2359.0  1963.421053          104.250000
# تاريخي               8.5  1962.277778          107.133333
# جريمة             2258.5  1963.333333           98.200000
# حرب               2277.0  1964.777778          109.222222
# حركة              2320.5  1965.400000          101.459459
# خيال                18.0  1954.000000          120.000000
# خيال علمي         2342.0  1966.000000          111.666667
# دراما             1307.0  1962.803289          105.741379
# رعب                 19.0  1956.000000          115.000000
# رومانسي            317.0  1961.263456          106.254839
# رياضي             2283.0  1968.333333          108.333333
# سيرة ذاتية        2292.5  1964.125000          126.142857
# عائلي             2102.5  1962.100000          104.625000
# غموض              2265.5  1977.500000          103.000000
# قصير              2269.5  1973.166667           33.666667
# ...

# %%
cat = df['تصنيف الفيلم'].unique()
dur = df_duration['مدة الفيلم (دقيقة)']
print(cat.shape)
print(dur.shape)
# Out:
# (20,)
# (20,)

# %%
plt.plot(cat, dur)
 
plt.xlabel('category')

plt.ylabel('average duration')

plt.show()
